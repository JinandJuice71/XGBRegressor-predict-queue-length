# %%
# %set_env GOOGLE_APPLICATION_CREDENTIALS=C:\Users\Mark\Desktop\PurdueEats-e85c448de7a4.json
# Out:
# env: GOOGLE_APPLICATION_CREDENTIALS=C:\Users\Mark\Desktop\PurdueEats-e85c448de7a4.json

# %% [raw]
# from google.cloud import bigquery
# import sys
# from backend.DB.Util import runQuery
# from backend.API.routes.menu import get_nutrition, nutrition_to_macros, get_menu_item
# import pandas as pd
# import datetime
#
# gcp_project = "purdueeats-304919"
# bq_dataset = "PurdueEatsDatabase"
#
# client = bigquery.Client(project=gcp_project)
# dataset_ref = client.dataset(bq_dataset)
#
# def userReviewsSummary(UserID):
#     reviews = runQuery( f"select user.UserID, MenuItemID, Rating, Timestamp from UserBasic as user Inner Join MenuItemsReviews as txn on user.UserID = txn.UserID WHERE user.UserID = {UserID}")
#     return reviews.to_dataframe()
#
# def allTransactionsSummary():
#     transactions = runQuery( f"select UserID, TransactionAmount, Balance, Timestamp from  UserTransaction ")
#     return transactions.to_dataframe()
#
#
# def getMenuItemName(MenuItemID):
#     rtn = runQuery( f"select ItemName from MenuItems WHERE MenuItemID = {MenuItemID}").to_dataframe()
#     rtn.columns = [''] * len(rtn.columns)
#     return rtn
#
# def getMenuItemDetails():
#     res = [dict(row) for row in runQuery(
#         f"select MenuItemID, ItemName, HashID from MenuItems")]
#
#     rtn = dict()
#     xtn = dict()
#
#     for x in res:
#         rtn[x['MenuItemID']] = x['ItemName']
#         xtn[x['MenuItemID']] = x['HashID']
#
#     return rtn, xtn

# %% [markdown]
# df = userReviewsSummary(7023699889393535879) #use 7023699889393535879 for example
# df['first_day_of_week'] = df["Timestamp"].apply(lambda df:
#                                         datetime.datetime(year=df.year, month=df.month, day=df.day))
# df.set_index(df["first_day_of_week"], inplace=True) #makes lines 56-59 run
#
# calories = [] #these empty lists will be populated with in the for loop below, then added as columns to dataset.
# carbs = []
# fat = []
# protein = []
# menuItemStr = []
#
# for i, row in df.iterrows():
#     menu_item_id = row[1] #this is the menu item id
#     menuItemStr.append(getMenuItemName(menu_item_id).loc[0].to_string()[4:])
#     response = get_nutrition(menu_item_id)
#     _calories, _carbs, _fat, _protein = nutrition_to_macros(response)
#     calories.append(_calories)
#     carbs.append(_carbs)
#     fat.append(_fat)
#     protein.append(_protein)
# df['calories'] = calories
# df['carbs'] = carbs
# df['fat'] = fat
# df['protein'] = protein
# df['menuItemStr'] = menuItemStr
#
# weekly_avg_calories = df.calories.resample('W').sum() / df.first_day_of_week.resample('W').count()
# weekly_avg_carbs = df.carbs.resample('W').sum() / df.first_day_of_week.resample('W').count()
# weekly_avg_fat = df.fat.resample('W').sum() / df.first_day_of_week.resample('W').count()
# weekly_avg_protein = df.protein.resample('W').sum() / df.first_day_of_week.resample('W').count()
# #sum of total calories per week / number of active input days per week
#
# #counting unique occurences
# df['menuItemStr'] = df['menuItemStr'].str.split()
# menu_item_count = df['menuItemStr'].apply(pd.Series).stack().reset_index(drop=True).value_counts()
# #menu_item_count = df['MenuItemID'].value_counts() #obsolete line that returns menu item id with count
#
# # this is to calculate user transactions
# df2 = userTransactionsSummary(7023699889393535879)
# df2['first_day_of_week'] = df2["Timestamp"].apply(lambda df2:
#                                         datetime.datetime(year=df2.year, month=df2.month, day=df2.day))
# df2.set_index(df2["first_day_of_week"], inplace=True) #makes line 74 run
# weekly_summary_trans = df2.TransactionAmount.resample('W').sum()
#
# print("\nMenu Item Count is used for word cloud. It contains the menu item # followed by the count.")
# print(f"\nmenu_item_count: \n{menu_item_count}") #frequency count of menu items; for word cloud
#
# print("\nWeekly macro averages are below. They're in Series format and can thus be plotted. The index is the first day of the week, the values are average macro consumed of that week")
# print(f"\nweekly_avg_calories: \n{weekly_avg_calories}") #this is a series
# print(f"\nweekly_avg_carbs: \n{weekly_avg_carbs}")  # this is a series
# print(f"\nweekly_avg_fat: \n{weekly_avg_fat}") #this is a series
# print(f"\nweekly_avg_protein: \n{weekly_avg_protein}") #this is a series
# print("\nWeekly sum transactions averages are below. They're in the same format as above.")
# print(f"\nweekly_summary_trans \n{weekly_summary_trans}") #this is a series.

# %%
def mealPlanSummary():
    mealPlans = runQuery( f"SELECT * FROM UserExtra")
    return mealPlans.to_dataframe()

# %%
mealPlansDF = mealPlanSummary()
mealPlansDF
# Out:
# <google.cloud.bigquery.table.RowIterator object at 0x00000173AA68C250>
#                  UserID       MealPlanName  MealSwipeCount  \
# 0   2810710999154368828  21 Meal Plan +250              21
# 1  -4903962852921021689  21 Meal Plan +250              21
# 2   -786297260319589266  15 Meal Plan +450              15
# 3   7023699889393535879  21 Meal Plan +500              21
# 4   6967645914836607210  10 Meal Plan +100              10
# 5   8882272202218536392  10 Meal Plan +100              10
# 6  -8325608802771069211  10 Meal Plan +100              10
# 7  -4518613502442612524  15 Meal Plan +450              15
# 8  -1671267070407422883  15 Meal Plan +450              15
# 9   4467606805034911759  15 Meal Plan +450              15
# 10  -644379582692266724  15 Meal Plan +450              15
# 11  1589774858082006536  15 Meal Plan +450              15
# 12 -2242890609849612160  15 Meal Plan +450              15
# 13  8788104928683024331  15 Meal Plan +450              15
# 14  4087605085059207658  15 Meal Plan +450              15
# 15  2095955503326350370  15 Meal Plan +450              15
# 16   737319298931306801  15 Meal Plan +450              15
# 17  8099793272915706690  15 Meal Plan +450              15
# 18 -9001107976745399192  21 Meal Plan +250              21
# 19 -8488187732628473157  21 Meal Plan +250              21
# 20 -2589269694930711347  21 Meal Plan +250              21
# 21  8868460133119895895  21 Meal Plan +250              21
# 22  6295342170354506735  21 Meal Plan +250              21
# 23 -6972977857218552086  21 Meal Plan +500              21
# 24 -2950671479005323586  21 Meal Plan +500              21
# 25  3028983648645194487  21 Meal Plan +500              21
# 26 -7051850150604121449  21 Meal Plan +500              21
#
#     DiningDollarBalance
# 0                 250.0
# 1                 250.0
# 2                 340.0
# 3                 500.0
# 4                 100.0
# 5                 100.0
# 6                 100.0
# 7                 410.0
# 8                 450.0
# 9                 450.0
# 10                405.0
# 11                950.0
# 12                450.0
# 13                450.0
# 14                420.0
# 15                450.0
# 16                450.0
# 17                416.0
# 18                250.0
# 19                250.0
# 20                250.0
# 21                250.0
# 22                250.0
# 23                500.0
# 24               1500.0
# 25                500.0
# 26                700.0

# %%
import matplotlib.pyplot as plt
mealPlansDF.MealPlanName.value_counts(sort=False).plot.pie(figsize = (7,7))
my_circle=plt.Circle( (0,0), 0.7, color='white')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()

# %%
def getAllUsers():
    allUsers = runQuery(f"SELECT UserID FROM UserBasic")
    return allUsers.to_dataframe()
allUserID = getAllUsers()
# Out:
# <google.cloud.bigquery.table.RowIterator object at 0x00000173AEDD9040>

# %%
#WARNING: RUNTIME IS LIKE A MINUTE NOW
#get all the menu items all users have consumed
rtn, xtn = getMenuItemDetails()

masterList = []

for UserID in allUserID.UserID.tolist():
    print(UserID)
    df = userReviewsSummary(UserID) #use 7023699889393535879 for example
    
    def get_value(keyy, my_dict):
        for key, value in my_dict.items():
            if key == keyy:
                return value
 
        return "key doesn't exist"

    df.MenuItemID = df.MenuItemID.apply(lambda x: get_value(x, rtn))
    df.MenuItemID = df.MenuItemID.astype(str)
    #print(df.MenuItemID)
    #display(df.dtypes)
    menuItemStr =df.MenuItemID.to_list()
    
    
    #counting unique occurences
    if not menuItemStr: #if the list is empty:
        print("User has made no reviews!")
    else:
        df['MenuItemID'] = df['MenuItemID'].str.split()
        masterList.append(df['MenuItemID'].apply(pd.Series).stack().reset_index(drop=True))
masterList
# Out:
# <google.cloud.bigquery.table.RowIterator object at 0x00000173AEE39F10>
# -4903962852921021689
# <google.cloud.bigquery.table.RowIterator object at 0x00000173AEE3DE80>
# -2242890609849612160
# <google.cloud.bigquery.table.RowIterator object at 0x00000173AEE45A60>
# -9001107976745399192
# <google.cloud.bigquery.table.RowIterator object at 0x00000173AEE4D850>
# -8488187732628473157
# <google.cloud.bigquery.table.RowIterator object at 0x00000173AEE6C310>
# 3028983648645194487
# <google.cloud.bigquery.table.RowIterator object at 0x00000173AEE6C550>
# 737319298931306801
# <google.cloud.bigquery.table.RowIterator object at 0x00000173AEE6C490>
# -1619648933082824640
# <google.cloud.bigquery.table.RowIterator object at 0x00000173AEE6C070>
# User has made no reviews!
# 4087605085059207658
# <google.cloud.bigquery.table.RowIterator object at 0x00000173AEE6C2B0>
# 8868460133119895895
# <google.cloud.bigquery.table.RowIterator object at 0x00000173AEF42C40>
# User has made no reviews!
# -2589269694930711347
# <google.cloud.bigquery.table.RowIterator object at 0x00000173AC918640>
# 6295342170354506735
# <google.cloud.bigquery.table.RowIterator object at 0x00000173AEE4D850>
# 6967645914836607210
# <google.cloud.bigquery.table.RowIterator object at 0x00000173AEF2A4F0>
# 8788104928683024331
# <google.cloud.bigquery.table.RowIterator object at 0x00000173AEE4D850>
# 1589774858082006536
# <google.cloud.bigquery.table.RowIterator object at 0x00000173AEF35E50>
# 4467606805034911759
# <google.cloud.bigquery.table.RowIterator object at 0x00000173AEF3DF40>
# -1671267070407422883
# <google.cloud.bigquery.table.RowIterator object at 0x00000173AEF35AF0>
# 8882272202218536392
# <google.cloud.bigquery.table.RowIterator object at 0x00000173AEF35580>
# User has made no reviews!
# -644379582692266724
# <google.cloud.bigquery.table.RowIterator object at 0x00000173AEF35EB0>
# 2095955503326350370
# <google.cloud.bigquery.table.RowIterator object at 0x00000173AEF31D30>
# 7023699889393535879
# <google.cloud.bigquery.table.RowIterator object at 0x00000173AEF2AA60>
# -2950671479005323586
# <google.cloud.bigquery.table.RowIterator object at 0x00000173AEF2A700>
# -6972977857218552086
# <google.cloud.bigquery.table.RowIterator object at 0x00000173AEF2A460>
# -4518613502442612524
# <google.cloud.bigquery.table.RowIterator object at 0x00000173AEF35400>
# 0
# <google.cloud.bigquery.table.RowIterator object at 0x00000173AEF3D760>
# -7051850150604121449
# <google.cloud.bigquery.table.RowIterator object at 0x00000173AEF3DAF0>
# 3183534950451599476
# <google.cloud.bigquery.table.RowIterator object at 0x00000173AEF19D30>
# User has made no reviews!
# -5179890033796933917
# <google.cloud.bigquery.table.RowIterator object at 0x00000173AEF19730>
# User has made no reviews!
# 8099793272915706690
# <google.cloud.bigquery.table.RowIterator object at 0x00000173AEF199A0>
# -8325608802771069211
# <google.cloud.bigquery.table.RowIterator object at 0x00000173AEF19730>
# -7967665590231560711
# <google.cloud.bigquery.table.RowIterator object at 0x00000173AEF193A0>
# User has made no reviews!
# -786297260319589266
# <google.cloud.bigquery.table.RowIterator object at 0x00000173AEF192B0>
# User has made no reviews!
# 2810710999154368828
# <google.cloud.bigquery.table.RowIterator object at 0x00000173AEF19AC0>
# [0        Plain
#  1        Bagel
#  2        Fresh
#  3     Broccoli
#  4      Florets
#  5      Roasted
#  6     Seasoned
#  7     Broccoli
#  8         Mini
#  9       Spring
#  10       Rolls
#  dtype: object,
#  0          Green
#  1          Beans
#  2           Beef
#  3          Gravy
#  4       Homemade
#           ...
#  150         Eggs
#  151    Scrambled
#  152         With
#  153      Cheddar
#  154       Cheese
#  Length: 155, dtype: object,
#  0          Peach
#  1         Slices
#  2           Mozz
#  3          Style
#  4       Shredded
#  5          Vegan
#  6         Cheese
#  7          Cajun
#  8        Grilled
#  9        Chicken
#  10        Breast
#  11       BoilerQ
#  12           BBQ
#  13       Chicken
#  14     Drumstick
#  15         Pesto
#  16    Tortellini
#  17      Shredded
#  18       Lettuce
#  19          Oreo
#  20        Cookie
#  21       Blondie
#  22       Brownie
#  23         Fried
#  24      Potatoes
#  25       Roasted
#  26        Garlic
#  27        Butter
#  28       Carrots
#  dtype: object,
#  0     Quesadilla
#  1        Toppers
#  2           Beef
#  3            and
#  4      Mushrooms
#  5             in
#  6          Cream
#  7          Sauce
#  8         Creamy
#  9       Coleslaw
#  10       Oatmeal
#  11        Raisin
#  12        Cookie
#  13       Oatmeal
#  14          Thin
#  15           Cut
#  16         Fries
#  dtype: object,
#  0          Gluten
#  1            Free
#  2       Blueberry
#  3          Muffin
#  4           Panko
#  5         Breaded
#  6            Fish
#  7         Italian
#  8             Ice
#  9          Banana
#  10           Hash
#  11          Brown
#  12          Patty
#  13        Raisins
#  14          Maple
#  15          Syrup
#  16     Devilsfood
#  17           Cake
#  18           with
#  19    Buttercream
#  20         Ranger
#  21         Cookie
#  22            Red
#  23        Jasmine
#  24           Rice
#  dtype: object,
#  0    Oatmeal
#  1       Thin
#  2        Cut
#  3      Fries
#  4    Oatmeal
#  5     Raisin
#  6     Cookie
#  dtype: object,
#  0         Peanut
#  1         Butter
#  2      Hopscotch
#  3            Bar
#  4         w/Nuts
#           ...
#  423       Pulled
#  424         Pork
#  425       Korean
#  426       Pulled
#  427         Pork
#  Length: 428, dtype: object,
#  0      Sundried
#  1        Tomato
#  2       Risotto
#  3       Raisins
#  4       Vanilla
#           ...
#  210        Gold
#  211     Pancake
#  212    Sundried
#  213      Tomato
#  214     Risotto
#  Length: 215, dtype: object,
#  0          Cream
#  1          Gravy
#  2        Italian
#  3        Sausage
#  4          Green
#  5        Peppers
#  6            and
#  7         Onions
#  8         Banana
#  9           Cake
#  10          with
#  11        Banana
#  12      Frosting
#  13    Mozzarella
#  14        Cheese
#  15       Sausage
#  16         Pizza
#  17          Meat
#  18       Lasagna
#  19         Maple
#  20         Baked
#  21         Beans
#  22        Smoked
#  23          Beef
#  24       Brisket
#  25       Grilled
#  26          Pork
#  27    Tenderloin
#  28           BBQ
#  29          Tofu
#  30           and
#  31       Peppers
#  32          Feta
#  33        Cheese
#  dtype: object,
#  0         Apple
#  1            Hi
#  2           Pie
#  3         Baked
#  4        French
#           ...
#  131     Roasted
#  132       Green
#  133       Beans
#  134       Flour
#  135    Tortilla
#  Length: 136, dtype: object,
#  0            Lemon
#  1            Cream
#  2             Cake
#  3            Salsa
#  4              Cup
#  5           Garlic
#  6           Mashed
#  7         Potatoes
#  8          Vanilla
#  9        Sunflower
#  10          Butter
#  11            Hard
#  12          Cooked
#  13            Eggs
#  14          Orange
#  15          Sliced
#  16    Strawberries
#  17          Gluten
#  18            Free
#  19       Blueberry
#  20          Muffin
#  21          Banana
#  22            Pork
#  23     Potstickers
#  24           Brown
#  25           Sugar
#  26           Salsa
#  27             Cup
#  28            Rice
#  29            Chex
#  30          Cereal
#  31        Sundried
#  32          Tomato
#  33         Risotto
#  34          Yellow
#  35            Corn
#  36        Tortilla
#  37            Rice
#  38            Chex
#  39          Cereal
#  40          Smokey
#  41           Links
#  42           Green
#  43           Beans
#  44         Raisins
#  45           Brown
#  46           Sugar
#  47         Oatmeal
#  48          Sliced
#  49    Strawberries
#  50           Baked
#  51          Potato
#  52        Meatless
#  53       Spaghetti
#  54           Sauce
#  55          Cashew
#  56         Chicken
#  dtype: object,
#  0           Sliced
#  1     Strawberries
#  2          Raisins
#  3             Hard
#  4           Cooked
#  5             Eggs
#  6             Rice
#  7             Chex
#  8           Cereal
#  9         Parmesan
#  10         Roasted
#  11      Fingerling
#  12        Potatoes
#  13       Meatballs
#  14            with
#  15        Marinara
#  16          Gluten
#  17            Free
#  18          Peanut
#  19          Butter
#  20          Cookie
#  21         Roasted
#  22       Chickpeas
#  23           Fried
#  24         Chicken
#  25          Gluten
#  26            Free
#  27            Sour
#  28           Patch
#  29             Kid
#  30        Cupcakes
#  31         Mexican
#  32          Fiesta
#  33            Rice
#  34         Buffalo
#  35         Chicken
#  36             Dip
#  37           Spicy
#  38             Red
#  39           Beans
#  40             and
#  41            Rice
#  42           Lemon
#  43         Chicken
#  44            Stir
#  45             Fry
#  46         Grilled
#  47             Hot
#  48             Dog
#  49          Loaded
#  50          Garlic
#  51         Smashed
#  52        Potatoes
#  dtype: object,
#  0          Rice
#  1          Chex
#  2        Cereal
#  3        Gluten
#  4          Free
#  5     Blueberry
#  6        Muffin
#  7         Brown
#  8         Sugar
#  9           Cup
#  10         Hand
#  11         Held
#  12        Fruit
#  13       Raisin
#  14          Cup
#  15         Kiwi
#  16      Oatmeal
#  dtype: object,
#  0        Roasted
#  1          Grape
#  2       Tomatoes
#  3       Cinnamon
#  4         Muffin
#  5         Turkey
#  6         Burger
#  7           Beef
#  8          Gravy
#  9        Kimchee
#  10         Cajun
#  11       Chicken
#  12    Drumsticks
#  13           New
#  14          York
#  15        Garlic
#  16         Bread
#  17         Chick
#  18           Pea
#  19        Chhole
#  20        Indian
#  21        Korean
#  22          Pork
#  23          Chop
#  dtype: object,
#  0       Meatballs
#  1            with
#  2        Marinara
#  3        Nsayel's
#  4         Chicken
#  5          Breast
#  6     Gluten-Free
#  7           White
#  8           Bread
#  9          Raisin
#  10            Cup
#  11           Rice
#  12           Chex
#  13         Cereal
#  14        Brownie
#  15      Chocolate
#  16         Mousse
#  dtype: object,
#  0     Chocolate
#  1          Chip
#  2        Muffin
#  3           Red
#  4        Velvet
#  5          Ooey
#  6         Gooey
#  7          Cake
#  8           Bar
#  9         Flour
#  10     Tortilla
#  11         Oven
#  12      Roasted
#  13          Red
#  14     Potatoes
#  15     Szechuan
#  16         Beef
#  17          and
#  18      Seafood
#  19        Vegan
#  20           Ma
#  21           Po
#  22         Tofu
#  dtype: object,
#  0          Roasted
#  1            Sweet
#  2         Potatoes
#  3        Pineapple
#  4           Chunks
#  5          Mexican
#  6             Rice
#  7            Santa
#  8               Fe
#  9             Corn
#  10         Raisins
#  11         Cookies
#  12               N
#  13           Cream
#  14          Delish
#  15         Dessert
#  16         Raisins
#  17           Brown
#  18           Sugar
#  19         Raisins
#  20          Sliced
#  21    Strawberries
#  dtype: object,
#  0          Sweet
#  1            and
#  2           Sour
#  3           Tofu
#  4        Pickled
#  5      Cucumbers
#  6        Chicken
#  7          Tikka
#  8         Masala
#  9         Grated
#  10      Parmesan
#  11        Cheese
#  12          Long
#  13         Grain
#  14          Rice
#  15         Coney
#  16        Island
#  17         Sauce
#  18         Baked
#  19       Chicken
#  20       Sausage
#  21         Links
#  22            Au
#  23        Gratin
#  24      Potatoes
#  25        Sesame
#  26       Chinese
#  27         Sauce
#  28       Roasted
#  29         Cajun
#  30       Chicken
#  31    Drumsticks
#  32           MYO
#  33           Pho
#  34        Noodle
#  35          Bowl
#  36       Roasted
#  37         Honey
#  38        Ginger
#  39          Pork
#  40          Loin
#  41         Greek
#  42     Marinated
#  43    Portabella
#  44     Mushrooms
#  dtype: object,
#  0          Jumbo
#  1          White
#  2      Chocolate
#  3           Chip
#  4         Muffin
#  5          Baked
#  6         Potato
#  7     Vegetarian
#  8          Chili
#  9         Indian
#  10        Spiced
#  11       Roasted
#  12      Potatoes
#  13     Vegetable
#  14           Pot
#  15           Pie
#  16    Steakhouse
#  17          Pork
#  18          Chop
#  19          Mild
#  20       Picante
#  21         Sauce
#  22        Hearty
#  23        Grains
#  24           and
#  25          Wild
#  26     Mushrooms
#  27         Santa
#  28            Fe
#  29          Corn
#  30         Farro
#  31          with
#  32         Ancho
#  33         Chili
#  34           and
#  35         White
#  36         Beans
#  37         Vegan
#  38        Quinoa
#  39           and
#  40       Peppers
#  41         Lemon
#  42         Poppy
#  43          Seed
#  44        Muffin
#  45        Menami
#  46     Marinated
#  47          Tofu
#  48         Mango
#  49        Chunks
#  50         Baked
#  51         Beans
#  52          Rice
#  53      Krispies
#  54           Bar
#  55         Steak
#  56         Fries
#  dtype: object,
#  0     Roasted
#  1    Broccoli
#  2       Salad
#  3         Bar
#  4     Italian
#  5         Ice
#  dtype: object,
#  0           Sliced
#  1     Strawberries
#  2          Raisins
#  3          Vanilla
#  4        Sunflower
#  5           Butter
#  6          Italian
#  7              Ice
#  8           French
#  9            Toast
#  10          Sticks
#  dtype: object,
#  0          Banana
#  1            Cake
#  2            with
#  3          Banana
#  4        Frosting
#            ...
#  355     Chocolate
#  356         Layer
#  357          Cake
#  358    Strawberry
#  359       Gelatin
#  Length: 360, dtype: object,
#  0    Quesadilla
#  1       Toppers
#  2          Corn
#  3          Pita
#  4         Sauce
#  dtype: object,
#  0         Baked
#  1         Sweet
#  2        Potato
#  3          Peas
#  4         Pesto
#  5       Alfredo
#  6         Cream
#  7         Sauce
#  8       Chicken
#  9       Sausage
#  10         Link
#  11         with
#  12    Cranberry
#  13      Coconut
#  14        Cream
#  15          Pie
#  16       Fritos
#  17         Corn
#  18        Chips
#  dtype: object,
#  0            Double
#  1         Chocolate
#  2              Chip
#  3            Cookie
#  4              Beef
#  5                 N
#  6           Cheddar
#  7          Sandwich
#  8            Gluten
#  9              Free
#  10        Hamburger
#  11              Bun
#  12    Snickerdoodle
#  13           Cookie
#  14          Sausage
#  15            Gravy
#  16            Salad
#  17              Bar
#  18             Mini
#  19           Spring
#  20            Rolls
#  21          Supreme
#  22           Veggie
#  23       Quesadilla
#  24       Applesauce
#  25       Vegetarian
#  26            Chili
#  27          Italian
#  28          Sausage
#  29            Cuban
#  30             Pork
#  31             Loin
#  32        Scrambled
#  33             Eggs
#  34            Pesto
#  35          Alfredo
#  36            Cream
#  37            Sauce
#  38            Cajun
#  39          Chicken
#  40       Drumsticks
#  dtype: object]

# %%
flatList = [ item for elem in masterList for item in elem] #turn list of lists into single list
d = {x:flatList.count(x) for x in flatList}

# %%
from PIL import Image
import matplotlib.pyplot as plt
from wordcloud import WordCloud

wordcloud = WordCloud(width = 1000, height = 500).generate_from_frequencies(d)

plt.figure(figsize=(15,8))
plt.imshow(wordcloud)

# %%
#do all user transactions trends, user transactions trends per meal plan

# %%
transactions = allTransactionsSummary()
# Out:
# <google.cloud.bigquery.table.RowIterator object at 0x00000173AEF48E80>

# %%
transactions = transactions.sort_values(by=['Timestamp']) #sort df by time
transactions = transactions[transactions.UserID != 0] #get rid of userid 0 since that's admin
transactions = transactions[transactions.UserID != -2950671479005323586] #get rid of this weird transactoin that's -1000
transactions = transactions[transactions.UserID != -7051850150604121449] #same with t his guyS
transactions = transactions.drop(2)
transactions
# Out:
#                  UserID  TransactionAmount  Balance  \
# 31  2810710999154368828               1.00    79.00
# 30  2810710999154368828               3.00    76.00
# 26  -786297260319589266              10.00   340.00
# 34  2810710999154368828              10.00    66.00
# 33  2810710999154368828              15.00    51.00
# 23  -786297260319589266              10.00   350.00
# 29  2810710999154368828              20.00    31.00
# 35  2810710999154368828              28.00     3.00
# 32  2810710999154368828              24.00   -21.00
# 25  -786297260319589266              30.00   380.00
# 37  -786297260319589266              40.00   410.00
# 36  2810710999154368828              40.00   -61.00
# 16  7023699889393535879              12.00   108.34
# 13  7023699889393535879               3.00   129.34
# 1   1589774858082006536              56.00   394.00
# 14  7023699889393535879               4.00   125.34
# 15  7023699889393535879               5.00   120.34
# 12  7023699889393535879               1.00   132.34
# 11  7023699889393535879               6.66   133.34
# 5   7023699889393536000              10.00   330.00
# 6   7023699889393536000              10.00   340.00
# 7   7023699889393536000              10.00   320.00
# 24  -786297260319589266              20.00   360.00
# 10  7023699889393535879              90.00   140.00
# 21 -4518613502442612524              25.00   410.00
# 20 -4518613502442612524              15.00   435.00
# 17  4087605085059207658              10.00   435.00
# 18  4087605085059207658              15.00   420.00
# 19  -644379582692266724              45.00   405.00
# 22  8099793272915706690              34.00   416.00
# 28  2810710999154368828              10.00    80.00
#
#                           Timestamp
# 31 2021-01-22 20:19:47.599000+00:00
# 30 2021-01-30 20:19:47.599000+00:00
# 26 2021-01-30 20:19:47.599000+00:00
# 34 2021-02-05 20:19:47.599000+00:00
# 33 2021-02-10 20:19:47.599000+00:00
# 23 2021-02-10 20:19:47.599000+00:00
# 29 2021-02-20 20:19:47.599000+00:00
# 35 2021-03-01 20:19:47.599000+00:00
# 32 2021-03-06 20:19:47.599000+00:00
# 25 2021-03-10 20:19:47.599000+00:00
# 37 2021-03-12 20:19:47.599000+00:00
# 36 2021-03-12 20:19:47.599000+00:00
# 16 2021-03-13 06:17:02.034000+00:00
# 13 2021-04-01 06:17:02.034000+00:00
# 1         2021-04-02 19:41:22+00:00
# 14 2021-04-04 06:17:02.034000+00:00
# 15 2021-04-05 06:17:02.034000+00:00
# 12 2021-04-10 06:17:02.034000+00:00
# 11 2021-04-10 06:17:02.034000+00:00
# 5  2021-04-10 06:17:02.034000+00:00
# 6  2021-04-10 06:17:02.034000+00:00
# 7  2021-04-10 06:17:02.034000+00:00
# 24 2021-04-10 20:19:47.599000+00:00
# 10 2021-04-12 14:36:16.032000+00:00
# 21 2021-04-15 17:06:31.583000+00:00
# 20 2021-04-15 17:06:31.583000+00:00
# 17 2021-04-15 17:06:31.583000+00:00
# 18 2021-04-15 17:06:31.583000+00:00
# 19        2021-04-15 17:09:46+00:00
# 22        2021-04-15 17:11:15+00:00
# 28 2021-04-22 20:19:47.599000+00:00

# %%
plt.figure(figsize=(15, 15))
plt.plot(transactions.Timestamp,transactions.TransactionAmount)

# %%
merged = pd.merge(mealPlansDF, transactions, on="UserID", how='outer')

# %%
bp = merged.boxplot(by='MealPlanName', column=['TransactionAmount'], figsize=(12,8))
